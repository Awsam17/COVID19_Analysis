# %% [markdown]
# * Import needed modules :

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('covid19_Confirmed_dataset.csv')

# %% [markdown]
# * Check the dataset format :

# %%
dataset.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset.shape
# Out:
# (266, 104)

# %% [markdown]
# * Delete useless columns :

# %%
dataset.drop(["Lat","Long"],axis=1,inplace=True)

# %%
dataset.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset_aggregated = dataset.groupby("Country/Region").sum()

# %%
dataset_aggregated.head(20)
# Out:
#                                                         Province/State  \
# Country/Region
# Afghanistan                                                          0
# Albania                                                              0
# Algeria                                                              0
# Andorra                                                              0
# Angola                                                               0
# Antigua and Barbuda                                                  0
# Argentina                                                            0
# Armenia                                                              0
# Australia            Australian Capital TerritoryNew South WalesNor...
# Austria                                                              0
# Azerbaijan                                                           0
# Bahamas                                                              0
# ...

# %%
dataset_aggregated.drop(["Province/State"],axis=1,inplace=True)

# %%
dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1092     1176     1279
# Albania               0        0        0  ...      609      634      663
# Algeria               0        0        0  ...     2811     2910     3007
# Andorra               0        0        0  ...      717      723      723
# ...

# %%
dataset_aggregated.shape
# Out:
# (187, 100)

# %% [markdown]
# * Visualize data for certain country :

# %%
dataset_aggregated.loc["China"].plot()
dataset_aggregated.loc["Albania"].plot()
plt.legend()

# %%
dataset_aggregated.loc["China"][:3].plot()
# Out:
# <Axes: >

# %% [markdown]
# * Measure the spread of the virus :

# %%
dataset_aggregated.loc["China"].diff().plot()
# Out:
# <Axes: >

# %% [markdown]
# * Maximum infection rate :

# %%
dataset_aggregated.loc["China"].diff().max()
# Out:
# 15136.0

# %%
dataset_aggregated.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
dataset_aggregated.loc["Spain"].diff().max()
# Out:
# 9630.0

# %% [markdown]
# * Max infection rate of all countries

# %%
countries = list(dataset_aggregated.index)

# %%
max_infection_rate = []
for c in countries :
  max_infection_rate.append(dataset_aggregated.loc[c].diff().max())

# %%
max_infection_rate
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
dataset_aggregated["max_infection_rate"] = max_infection_rate

# %%
dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
corona_dataset = pd.DataFrame(dataset_aggregated["max_infection_rate"])
corona_dataset.head()
# Out:
#                 max_infection_rate
# Country/Region
# Afghanistan                  232.0
# Albania                       34.0
# Algeria                      199.0
# Andorra                       43.0
# Angola                         5.0

# %% [markdown]
# * Analyze another related dataset :

# %%
happiness_report = pd.read_csv("worldwide_happiness_report.csv")

# %% [markdown]
# * Check the dataset :

# %%
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
happiness_report.shape
# Out:
# (156, 9)

# %% [markdown]
# * Drop useless columns :

# %%
useless_cols = ["Overall rank","Score","Generosity","Perceptions of corruption"]

# %%
happiness_report.drop(useless_cols,axis=1,inplace=True)

# %%
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report_agg = happiness_report.groupby("Country or region").sum()

# %%
happiness_report_agg.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Afghanistan                 0.350           0.517                    0.361
# Albania                     0.947           0.848                    0.874
# Algeria                     1.002           1.160                    0.785
# Argentina                   1.092           1.432                    0.881
# Armenia                     0.850           1.055                    0.815
#
#                    Freedom to make life choices
# Country or region
# Afghanistan                               0.000
# Albania                                   0.383
# Algeria                                   0.086
# Argentina                                 0.471
# Armenia                                   0.283

# %%
dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
dataset_aggregated.shape
# Out:
# (187, 101)

# %%
happiness_report_agg.shape
# Out:
# (156, 4)

# %%
final_dataset = corona_dataset.join(happiness_report_agg,how="inner")
final_dataset.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
final_dataset.shape
# Out:
# (143, 5)

# %% [markdown]
# * Correlation matrix :

# %%
final_dataset.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# max_infection_rate                                0.078196
# ...

# %% [markdown]
# * GDP vs Max infection rate :

# %%
x = final_dataset["GDP per capita"]
y = final_dataset["max_infection_rate"]
sns.scatterplot(x=x,y=np.log(y))
# to solve high scaling difference between x and y use log to the highest scaling axis
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <Axes: xlabel='GDP per capita', ylabel='max_infection_rate'>

# %%
sns.scatterplot(x=final_dataset["Social support"],y=np.log(final_dataset["max_infection_rate"]))
# Out:
# <Axes: xlabel='Social support', ylabel='max_infection_rate'>

# %%
sns.regplot(x=final_dataset["Social support"],y=np.log(final_dataset["max_infection_rate"]))
# Out:
# <Axes: xlabel='Social support', ylabel='max_infection_rate'>

# %%
dataset_corona_death = pd.read_csv("covid19_deaths_dataset.csv")
dataset_corona_death.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
dataset_corona_death.drop("Province/State",axis=1,inplace=True)
dataset_corona_death.head()
# Out:
#   Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0    Afghanistan  33.0000  65.0000        0        0        0        0
# 1        Albania  41.1533  20.1683        0        0        0        0
# 2        Algeria  28.0339   1.6596        0        0        0        0
# 3        Andorra  42.5063   1.5218        0        0        0        0
# 4         Angola -11.2027  17.8739        0        0        0        0
#
#    1/26/20  1/27/20  1/28/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0       47       50       57       58       60       64
# ...

# %%
dataset_corona_death.drop(["Lat","Long"],axis=1,inplace=True)
dataset_corona_death.head()
# Out:
#   Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 0    Afghanistan        0        0        0        0        0        0
# 1        Albania        0        0        0        0        0        0
# 2        Algeria        0        0        0        0        0        0
# 3        Andorra        0        0        0        0        0        0
# 4         Angola        0        0        0        0        0        0
#
#    1/28/20  1/29/20  1/30/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...       36       40       42       43
# 1        0        0        0  ...       26       27       27       27
# 2        0        0        0  ...      392      402      407      415
# 3        0        0        0  ...       37       37       37       40
# 4        0        0        0  ...        2        2        2        2
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0       47       50       57       58       60       64
# ...

# %%
dataset_corona_death_agg = dataset_corona_death.groupby("Country/Region").sum()
dataset_corona_death_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/21/20  4/22/20  4/23/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       36       40       42
# Albania               0        0        0  ...       26       27       27
# Algeria               0        0        0  ...      392      402      407
# Andorra               0        0        0  ...       37       37       37
# ...

# %% [markdown]
# * Deaths rate :

# %%
dataset_corona_death_agg.loc["China"].diff().plot()
# Out:
# <Axes: >

# %%
dataset_corona_death_agg.loc["Spain"].diff().plot()
# Out:
# <Axes: >

# %%
dataset_corona_death_agg.loc["Italy"].diff().plot()
# Out:
# <Axes: >

# %%
max_deaths_rate = []
countries = list(dataset_corona_death_agg.index)
for i in countries :
  max_deaths_rate.append(dataset_corona_death_agg.loc[i].diff().max())

# %%
dataset_corona_death_agg["max_deaths_rate"] = max_deaths_rate

# %%
dataset_corona_death_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...       40       42       43
# Albania               0        0        0  ...       27       27       27
# Algeria               0        0        0  ...      402      407      415
# Andorra               0        0        0  ...       37       37       40
# ...

# %%
corona_death_final = pd.DataFrame(dataset_corona_death_agg["max_deaths_rate"])
corona_death_final.head()
# Out:
#                 max_deaths_rate
# Country/Region
# Afghanistan                 7.0
# Albania                     4.0
# Algeria                    30.0
# Andorra                     4.0
# Angola                      2.0

# %%
final_dataset.shape
# Out:
# (143, 5)

# %%
corona_death_final.shape
# Out:
# (187, 1)

# %%
Dataset = final_dataset.join(corona_death_final,how="inner")
Dataset.head()
# Out:
#              max_infection_rate  GDP per capita  Social support  \
# Afghanistan               232.0           0.350           0.517
# Albania                    34.0           0.947           0.848
# Algeria                   199.0           1.002           1.160
# Argentina                 291.0           1.092           1.432
# Armenia                   134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices  \
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283
#
#              max_deaths_rate
# Afghanistan              7.0
# Albania                  4.0
# Algeria                 30.0
# Argentina               13.0
# ...

# %%
Dataset.corr()
# Out:
#                               max_infection_rate  GDP per capita  \
# max_infection_rate                      1.000000        0.250118
# GDP per capita                          0.250118        1.000000
# Social support                          0.191958        0.759468
# Healthy life expectancy                 0.289263        0.863062
# Freedom to make life choices            0.078196        0.394603
# max_deaths_rate                         0.880597        0.259893
#
#                               Social support  Healthy life expectancy  \
# max_infection_rate                  0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
# max_deaths_rate                     0.204148                 0.309666
#
# ...

# %% [markdown]
# * Visualize correlation between infection rate and death rate :

# %%
x = Dataset["max_infection_rate"]
y = Dataset["max_deaths_rate"]
sns.scatterplot(x=np.log(x),y=y)
# Out:
# <Axes: xlabel='max_infection_rate', ylabel='max_deaths_rate'>

# %%
Dataset.to_csv("Corona_Analysis.csv", index=True)
